# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt

# %%
posts_and_comments = os.path.join('posts_and_comments.csv')
fb_df = pd.read_csv(posts_and_comments)
fb_df
# Out:
#        CommentTime CommentTimeStamp        Comment  \
# 0       1609253809             LOVE  Chey'Na Bunch
# 1       1609253585             LOVE  Chey'Na Bunch
# 2       1609253535             LOVE  Chey'Na Bunch
# 3       1609215959             LOVE  Chey'Na Bunch
# 4       1609127023             LOVE  Chey'Na Bunch
# ...            ...              ...            ...
# 23859   1301001273             LIKE  Chey'Na Bunch
# 23860   1298231606             LIKE  Chey'Na Bunch
# 23861   1297961659             LIKE  Chey'Na Bunch
# 23862   1297613305             LIKE  Chey'Na Bunch
# 23863   1296859323             LIKE  Chey'Na Bunch
#
#                                                 PostedBy Action  Attachments  \
# 0       Chey'Na Bunch reacted to Danielle Carter's post.    NaN          NaN
# 1      Chey'Na Bunch reacted to Durel Hairston Jr.'s ...    NaN          NaN
# 2           Chey'Na Bunch reacted to Sean Holley's post.    NaN          NaN
# ...

# %%
ts = fb_df['CommentTime']
fb_df = fb_df.drop(columns='CommentTimeStamp')
fb_df['CommentTime'] = pd.to_datetime(ts,unit='s', yearfirst=True)

# %%
fb_df['year'] = fb_df['CommentTime'].dt.year
fb_df['month'] = fb_df['CommentTime'].dt.month
fb_df['day'] = fb_df['CommentTime'].dt.day
fb_df['hour'] = fb_df['CommentTime'].dt.hour
fb_df.head()
# Out:
#           CommentTime        Comment  \
# 0 2020-12-29 14:56:49  Chey'Na Bunch
# 1 2020-12-29 14:53:05  Chey'Na Bunch
# 2 2020-12-29 14:52:15  Chey'Na Bunch
# 3 2020-12-29 04:25:59  Chey'Na Bunch
# 4 2020-12-28 03:43:43  Chey'Na Bunch
#
#                                             PostedBy Action  Attachments  \
# 0   Chey'Na Bunch reacted to Danielle Carter's post.    NaN          NaN
# 1  Chey'Na Bunch reacted to Durel Hairston Jr.'s ...    NaN          NaN
# 2       Chey'Na Bunch reacted to Sean Holley's post.    NaN          NaN
# 3   Chey'Na Bunch reacted to Toriano Thomas's photo.    NaN          NaN
# 4   Chey'Na Bunch reacted to Toriano Thomas's photo.    NaN          NaN
#
#   CommentGroup  CommentAttachments  AttachmentTimestamp  UploadIP  Title  \
# 0          NaN                 NaN                  NaN       NaN    NaN
# 1          NaN                 NaN                  NaN       NaN    NaN
# 2          NaN                 NaN                  NaN       NaN    NaN
# ...

# %%
#fb_df.drop(columns=['Timestamp'])
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23864 entries, 0 to 23863
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CommentTime          23864 non-null  datetime64[ns]
#  1   Comment              23864 non-null  object
#  2   PostedBy             23864 non-null  object
#  3   Action               8 non-null      object
#  4   Attachments          5 non-null      float64
#  5   CommentGroup         5 non-null      object
#  6   CommentAttachments   0 non-null      float64
#  7   AttachmentTimestamp  0 non-null      float64
#  8   UploadIP             0 non-null      float64
#  9   Title                0 non-null      float64
#  10  year                 23864 non-null  int64
#  11  month                23864 non-null  int64
#  12  day                  23864 non-null  int64
#  13  hour                 23864 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(4)
# ...

# %%
clean_c_pd = fb_df.drop(columns=['Attachments', 'CommentGroup', 'AttachmentTimestamp', 'UploadIP', 'Title', 'CommentAttachments'])
#new_df = fb_df.set_index(fb_df['Actor'])
clean_c_pd.head()
clean_c_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23864 entries, 0 to 23863
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CommentTime  23864 non-null  datetime64[ns]
#  1   Comment      23864 non-null  object
#  2   PostedBy     23864 non-null  object
#  3   Action       8 non-null      object
#  4   year         23864 non-null  int64
#  5   month        23864 non-null  int64
#  6   day          23864 non-null  int64
#  7   hour         23864 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 1.5+ MB
