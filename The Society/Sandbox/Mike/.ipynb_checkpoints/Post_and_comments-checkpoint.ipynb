# %%
import os
import matplotlib as mp
import pandas as pd
import plotly as pt
import numpy as np

# %%
p_pd = pd.read_csv('posts_and_comments.csv') #likes by me csv

# %%
p_pd['Timestamp'] = pd.to_datetime(p_pd['Timestamp'],unit='s', yearfirst=True)

# %%
p_pd['year'] = p_pd['Timestamp'].dt.year
p_pd['month'] = p_pd['Timestamp'].dt.month
p_pd['day'] = p_pd['Timestamp'].dt.day
p_pd['hour'] = p_pd['Timestamp'].dt.hour
p_pd.head()
# Out:
#             Timestamp Reaction           User  \
# 0 2021-02-24 01:03:54     LIKE  Michael Tyler
# 1 2021-02-23 03:13:00     LIKE  Michael Tyler
# 2 2021-02-23 03:11:43     LIKE  Michael Tyler
# 3 2021-02-23 01:29:05     LIKE  Michael Tyler
# 4 2021-02-23 01:17:14     LIKE  Michael Tyler
#
#                                           Action  Uri  year  month  day  hour
# 0      Michael Tyler likes Kanye Battle's photo.  NaN  2021      2   24     1
# 1          Michael Tyler likes BeGreat.'s photo.  NaN  2021      2   23     3
# 2  Michael Tyler likes Hari Sivaskandan's photo.  NaN  2021      2   23     3
# 3     Michael Tyler likes Taylor Johnson's post.  NaN  2021      2   23     1
# 4     Michael Tyler likes Brandon Cotton's post.  NaN  2021      2   23     1

# %%
p_pd = p_pd.drop(columns=['Uri'])

# %%
p_pd.head()
# Out:
#             Timestamp Reaction           User  \
# 0 2021-02-24 01:03:54     LIKE  Michael Tyler
# 1 2021-02-23 03:13:00     LIKE  Michael Tyler
# 2 2021-02-23 03:11:43     LIKE  Michael Tyler
# 3 2021-02-23 01:29:05     LIKE  Michael Tyler
# 4 2021-02-23 01:17:14     LIKE  Michael Tyler
#
#                                           Action  year  month  day  hour
# 0      Michael Tyler likes Kanye Battle's photo.  2021      2   24     1
# 1          Michael Tyler likes BeGreat.'s photo.  2021      2   23     3
# 2  Michael Tyler likes Hari Sivaskandan's photo.  2021      2   23     3
# 3     Michael Tyler likes Taylor Johnson's post.  2021      2   23     1
# 4     Michael Tyler likes Brandon Cotton's post.  2021      2   23     1

# %%
Likes = p_pd[p_pd['Reaction'] == 'LIKE'].count()
Loves = p_pd[p_pd['Reaction'] == 'LOVE'].count()
Haha = p_pd[p_pd['Reaction'] == 'HAHA'].count()
Reacts = p_pd['Reaction']
Years = p_pd['year'].unique()
Haha_count = (Haha[['Reaction', 'year']])
Loves_count = (Loves['Reaction'])
Likes_count = (Likes['Reaction'])

# %%
def Reaction(Reaction):
    if Reaction == "LIKE":
        return 0
    if Reaction == "HAHA":
        return 1
    if Reaction == "LOVE":
        return 2

# %%
p_pd["ReactionType"] = p_pd['Reaction'].map(Reaction)
plot = p_pd.groupby(['year'])
p_pd = p_pd.head(45)
months = p_pd.groupby('day').count()
pl1 = p_pd[['ReactionType', 'day']][p_pd['ReactionType'] == 0].count()
months = months.reset_index()
months.head(45)
# Out:
#     day  Timestamp  Reaction  User  Action  year  month  hour  ReactionType
# 0     1          2         2     2       2     2      2     2             2
# 1     4          7         7     7       7     7      7     7             7
# 2     6          1         1     1       1     1      1     1             1
# 3     8          1         1     1       1     1      1     1             1
# 4    13          1         1     1       1     1      1     1             1
# 5    14          1         1     1       1     1      1     1             1
# 6    15          1         1     1       1     1      1     1             1
# 7    16          4         4     4       4     4      4     4             4
# 8    18          2         2     2       2     2      2     2             2
# 9    19          4         4     4       4     4      4     4             4
# 10   22          5         5     5       5     5      5     5             5
# 11   23          5         5     5       5     5      5     5             5
# 12   24          3         3     3       3     3      3     3             3
# 13   25          3         3     3       3     3      3     3             3
# 14   29          2         2     2       2     2      2     2             2
# 15   31          3         3     3       3     3      3     3             3

# %%
p_pd.head()
#must group by day/hour/month/year i.e
pyear = p_pd.groupby(['day', 'month']).count() #grouping by day and month
pyear.head()
# Out:
#            Timestamp  Reaction  User  Action  year  hour  ReactionType
# day month
# 1   2              2         2     2       2     2     2             2
# 4   2              7         7     7       7     7     7             7
# 6   2              1         1     1       1     1     1             1
# 8   2              1         1     1       1     1     1             1
# 13  2              1         1     1       1     1     1             1

# %%
months.plot.bar(x='day', y='ReactionType')
# Out:
# <AxesSubplot:xlabel='day'>
