# %%
import os
import matplotlib as mp
import pandas as pd
import plotly as pt

# %%
c_pd = pd.read_csv('commentsTyler.csv') #comments csv
p_pd = pd.read_csv('post_and_comments.csv') #likes by me csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-890426a70f96> in <module>
#       1 c_pd = pd.read_csv('commentsTyler.csv') #comments csv
# ----> 2 p_pd = pd.read_csv('post_and_comments.csv') #likes by me csv
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
tm = c_pd['CommentTime']
c_pd['CommentTime'] = pd.to_datetime(tm,unit='s', yearfirst=True)
c_pd = c_pd.drop(columns='CommentTimeStamp')
c_pd
# Out:
#              CommentTime                                            Comment  \
# 0    2021-02-18 21:49:33  James Alberse true, plus if you really wanted ...
# 1    2021-02-18 21:07:28  honestly, can't you find out half of people's ...
# 2    2021-01-29 16:59:27                      The kitchen scene enough said
# 3    2021-01-25 17:08:43                                   Happy Birthday!!
# 4    2021-01-18 21:23:09  He's a grown up, I remember when he was just a...
# ...                  ...                                                ...
# 2198 2011-08-13 22:05:37                                             #NAME?
# 2199 2011-08-13 21:47:04                     lol shes a serial killer :O xD
# 2200 2011-08-13 21:41:56  LOL you texting at the movies rofl what chu wa...
# 2201 2011-08-13 21:40:06                             o.o what are you doing
# 2202 2011-08-13 21:39:05                         Oy komi what are you doing
#
# ...
