# %%
import os
import matplotlib as mp
import pandas as pd
import plotly as pt

# %%
c_pd = pd.read_csv('commentsTyler.csv') #comments csv

# %%
tm = c_pd['CommentTime'] #Variable for comment Time Column
c_pd['CommentTime'] = pd.to_datetime(tm,unit='s', yearfirst=True) #Convert time from seconds to expanded format
c_pd = c_pd.drop(columns='CommentTimeStamp')

# %%
c_pd['year'] = c_pd['CommentTime'].dt.year
c_pd['month'] = c_pd['CommentTime'].dt.month
c_pd['day'] = c_pd['CommentTime'].dt.day
c_pd['hour'] = c_pd['CommentTime'].dt.hour
c_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2203 entries, 0 to 2202
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CommentTime          2203 non-null   datetime64[ns]
#  1   Comment              2007 non-null   object
#  2   PostedBy             2016 non-null   object
#  3   Action               2203 non-null   object
#  4   Attachments          7 non-null      object
#  5   CommentGroup         46 non-null     object
#  6   CommentAttachments   19 non-null     object
#  7   AttachmentTimestamp  18 non-null     float64
#  8   UploadIP             18 non-null     object
#  9   Title                0 non-null      float64
#  10  year                 2203 non-null   int64
#  11  month                2203 non-null   int64
#  12  day                  2203 non-null   int64
#  13  hour                 2203 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(7)
# memory usage: 241.1+ KB

# %%
clean_c_pd = c_pd.drop(columns=['Attachments', 'CommentGroup', 'AttachmentTimestamp', 'UploadIP', 'Title', 'CommentAttachments'])

# %%
clean_c_pd.head()
clean_c_pd
# Out:
#              CommentTime                                            Comment  \
# 0    2021-02-18 21:49:33  James Alberse true, plus if you really wanted ...
# 1    2021-02-18 21:07:28  honestly, can't you find out half of people's ...
# 2    2021-01-29 16:59:27                      The kitchen scene enough said
# 3    2021-01-25 17:08:43                                   Happy Birthday!!
# 4    2021-01-18 21:23:09  He's a grown up, I remember when he was just a...
# ...                  ...                                                ...
# 2198 2011-08-13 22:05:37                                             #NAME?
# 2199 2011-08-13 21:47:04                     lol shes a serial killer :O xD
# 2200 2011-08-13 21:41:56  LOL you texting at the movies rofl what chu wa...
# 2201 2011-08-13 21:40:06                             o.o what are you doing
# 2202 2011-08-13 21:39:05                         Oy komi what are you doing
#
#            PostedBy                                             Action  year  \
# 0     Michael Tyler          Michael Tyler replied to his own comment.  2021
# 1     Michael Tyler     Michael Tyler commented on Eric Putman's post.  2021
# 2     Michael Tyler  Michael Tyler commented on Corey Williams's post.  2021
# 3     Michael Tyler  Michael Tyler commented on Angel Joyce Powell'...  2021
# 4     Michael Tyler  Michael Tyler commented on Gabriella Atwood's ...  2021
# ...             ...                                                ...   ...
# 2198  Michael Tyler           Michael Tyler commented on his own post.  2011
# 2199  Michael Tyler  Michael Tyler commented on Camille De Perio's ...  2011
# 2200  Michael Tyler           Michael Tyler commented on his own post.  2011
# 2201  Michael Tyler           Michael Tyler commented on his own post.  2011
# 2202  Michael Tyler           Michael Tyler commented on his own post.  2011
#
#       month  day  hour
# 0         2   18    21
# 1         2   18    21
# 2         1   29    16
# 3         1   25    17
# 4         1   18    21
# ...     ...  ...   ...
# 2198      8   13    22
# 2199      8   13    21
# 2200      8   13    21
# 2201      8   13    21
# 2202      8   13    21
#
# [2203 rows x 8 columns]

# %%
T-T x.x :) -_- _-_ o  .o  u.u c.c
