# %%
import os
import matplotlib as mp
import pandas as pd
import plotly as pt

# %%
fb_df = pd.read_csv('dataset_Facebook.csv', sep=';')
fb_df
# Out:
#      PageTotalLikes    Type  Category  PostMonth  PostWeekday  PostHour  Paid  \
# 0            139441   Photo         2         12            4         3   0.0
# 1            139441  Status         2         12            3        10   0.0
# 2            139441   Photo         3         12            3         3   0.0
# 3            139441   Photo         2         12            2        10   1.0
# 4            139441   Photo         2         12            2         3   0.0
# ..              ...     ...       ...        ...          ...       ...   ...
# 495           85093   Photo         3          1            7         2   0.0
# 496           81370   Photo         2          1            5         8   0.0
# 497           81370   Photo         1          1            5         2   0.0
# 498           81370   Photo         3          1            4        11   0.0
# 499           81370   Photo         2          1            4         4   NaN
#
# ...

# %%
fb_df = fb_df.dropna()

# %%
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495 entries, 0 to 498
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   PageTotalLikes                       495 non-null    int64
#  1   Type                                 495 non-null    object
#  2   Category                             495 non-null    int64
#  3   PostMonth                            495 non-null    int64
#  4   PostWeekday                          495 non-null    int64
#  5   PostHour                             495 non-null    int64
#  6   Paid                                 495 non-null    float64
#  7   LifetimeTotalReach                   495 non-null    int64
#  8   LifetimeTotalImpressions             495 non-null    int64
#  9   LifetimeEngagedUsers                 495 non-null    int64
#  10  LifetimePostConsumers                495 non-null    int64
# ...
