# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import plotly as pt

# %%
Faceset = os.path.join('../dataset_Facebook.csv')

# %%
fb_df = pd.read_csv(Faceset, sep=';')

# %%
fb_df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
indexes = fb_df[(fb_df['comment'] >= 1)].index
indexes
# Out:
# Int64Index([  0,   1,   3,   4,   5,   6,   9,  13,  14,  15,
#             ...
#             487, 488, 489, 490, 491, 493, 494, 495, 497, 498],
#            dtype='int64', length=394)

# %%
indexes = fb_df[(fb_df['share'] != 1) & (fb_df['comment'] != 1) & (fb_df['like'] != 1)].index
clfb_df = fb_df.drop(indexes)
clfb_df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 5              139441  Status         2          12             1          9
# 31             138895   Photo         2          12             3         10
# 39             138895   Photo         1          12             7          3
# 49             138353    Link         1          12             2          2
# 50             138353   Photo         2          11             1          9
# ..                ...     ...       ...         ...           ...        ...
# 478             86909   Photo         3           1             5         13
# 487             85979   Photo         3           1             1          2
# 489             85979   Photo         3           1             7          2
# 490             85979   Photo         3           1             6         11
# 491             85979   Photo         3           1             6          3
#
# ...

# %%
clfb_df['Post Hour'].unique()
# Out:
# array([ 3,  9, 10, 11,  2,  4,  8, 13, 12,  6,  5,  7,  1, 19, 18, 15, 14,
#        17, 16], dtype=int64)

# %%
fig, ax = plt.subplots()

# %%
ax.bar(clfb_df)
